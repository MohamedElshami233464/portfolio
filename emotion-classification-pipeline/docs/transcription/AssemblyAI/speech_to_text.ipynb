# %%
# importing packages
from pytubefix import YouTube
import os

# url input from youtube
yt = YouTube("https://youtu.be/Q9Hmo3EsvXA?si=9OQ3OARFLFSTtFNN")

# extract only audio
video = yt.streams.filter(only_audio=True).first()

# set destination to save file
destination = ("C:\Year 2\Y2- Block C")

# download the file
out_file = video.download(output_path=destination)

# save the file
base, ext = os.path.splitext(out_file)
new_file = base + '.mp3'
os.rename(out_file, new_file)

# %%
# importing packages
from pytubefix import YouTube
import os

# url input from youtube
yt = YouTube("https://youtu.be/Bdi_M2v5xT8?si=uiv4xPlGeCyFYbnK")

# extract only audio
video = yt.streams.filter(only_audio=True).first()

# set destination to save file
destination = ("C:\Year 2\Y2- Block C")

# download the file
out_file = video.download(output_path=destination)

# save the file
base, ext = os.path.splitext(out_file)
new_file = base + '.mp3'
os.rename(out_file, new_file)

# %%
import assemblyai as aai

# Set your API key
aai.settings.api_key = "b9fda34c29364c67af35bbffa8632ae2"

# Initialize transcriber
transcriber = aai.Transcriber()

# Upload your local file
upload_url =(r"c:\Year 2\Y2- Block C\The Blind Date Show 2 - Episode 54 with Jayda & Hattan.mp3")

print("File uploaded successfully:", upload_url)

# Configure transcription (with Arabic language support)
config = aai.TranscriptionConfig(speech_model=aai.SpeechModel.nano,language_code="ar")
# Transcribe the uploaded file
transcript = transcriber.transcribe(upload_url, config=config)

if transcript.status == aai.TranscriptStatus.error:
    print("Error:", transcript.error)
else:
    print("Transcription:", transcript.text)
# Out:
# File uploaded successfully: c:\Year 2\Y2- Block C\The Blind Date Show 2 - Episode 54 with Jayda & Hattan.mp3
# ...

# %%
import assemblyai as aai

# Set your API key
aai.settings.api_key = "b9fda34c29364c67af35bbffa8632ae2"

# Initialize transcriber
transcriber = aai.Transcriber()

# Upload your local file
upload_url =(r"c:\Year 2\Y2- Block C\The Blind Date Show 2 - Episode 20 with Malak & Sabbagh.mp3")

print("File uploaded successfully:", upload_url)

# Configure transcription (with Arabic language support)
config = aai.TranscriptionConfig(speech_model=aai.SpeechModel.nano,language_code="ar")
# Transcribe the uploaded file
transcript = transcriber.transcribe(upload_url, config=config)

if transcript.status == aai.TranscriptStatus.error:
    print("Error:", transcript.error)
else:
    print("Transcription:", transcript.text)
# Out:
# File uploaded successfully: c:\Year 2\Y2- Block C\The Blind Date Show 2 - Episode 20 with Malak & Sabbagh.mp3
# ...
